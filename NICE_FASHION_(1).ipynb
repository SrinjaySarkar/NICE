# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from sklearn import datasets,cluster,mixture
import numpy as np
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
import matplotlib.pyplot as plt
from google.colab import files
# %matplotlib inline

# %%
print(torch.cuda.is_available())
# %mkdir new_samples
# Out:
# True

# %%
class coupling_layer(torch.nn.Module):
    def __init__(self,in_dim,hidden_dim,hidden_layers,mask):
        super(coupling_layer, self).__init__()

        self.mask=mask
        self.hidden_layers=hidden_layers
        self.layer1=torch.nn.Linear(int(in_dim/2),hidden_dim)
        self.layer2=torch.nn.Linear(hidden_dim,hidden_dim)
        self.layer3=torch.nn.Linear(hidden_dim,int(in_dim/2))
        
    def forward(self,x,backward=False):
        #divide the flattened image tensor into 2 parts:
        #1:The first half dimensions (1:d/2)
        #2:The second half dimensions (d/2:D)
        #esentially gives us 2 half-images
        x=x.reshape((x.size()[0],x.size()[1]//2,2))
        first=x[:,:,0]
        second=x[:,:,1]
        if self.mask=="odd":
            x1=first
            x2=second
        else:
            x1=second
            x2=first
        #return (x2)
        mx2=self.layer1(x2)
        mx2=F.relu(mx2)
        for i in range(self.hidden_layers):
          mx2=self.layer2(mx2)
          mx2=F.relu(mx2)
        mx2=self.layer3(mx2)
        #mx2=F.relu(mx2)
        
        y1=x2#y1=x1:d/2
        #y2=x1:d/2+m(xd/2+1:D)
        if backward==True:
            y2=x1-mx2
        else:
            y2=x1+mx2
        if self.mask=="odd":
            x=torch.stack((y2,y1),dim=2)
        else:
            x=torch.stack((y1,y2),dim=2)
        x=x.reshape(x.shape[0],x.shape[1]*x.shape[2])
        return x

# %%
#scaling layer is added after the affine transformations
class scaling_layer(torch.nn.Module):
    def __init__(self,in_dim):
        super(scaling_layer,self).__init__()
        self.scaling_layer=torch.nn.Parameter(torch.zeros(in_dim))
        self.scaling_layer.requires_grad=True
    
    def forward(self,x,backward=False):
        if backward==True:
            x=x*torch.exp(-self.scaling_layer)
        else:
            x=x*torch.exp(self.scaling_layer)
        log_det_jacobian=torch.sum(self.scaling_layer)
        return (x,log_det_jacobian)

# %%
class NICE(torch.nn.Module):
    def __init__(self,prior_dist,n_coupling,in_dim,hidden_dim,hidden_layers):
        super(NICE,self).__init__()
        self.prior_dist=prior_dist
        self.n_coupling=n_coupling
        self.coupling_layers=torch.nn.ModuleList([coupling_layer(in_dim,hidden_dim,hidden_layers,mask="even") if i%2==0 else coupling_layer(in_dim,hidden_dim,hidden_layers,mask="odd") for i in range(self.n_coupling)])
        self.scaling_layers=scaling_layer(in_dim)
        
    def inference(self,x):#image_space ==> prior distribution
        for i in range(self.n_coupling):
            x=self.coupling_layers[i](x)
        x=self.scaling_layers(x)
        return (x)
    
    def sampling(self,z):#prior distribution ==> image space
        x,det_jacobian=self.scaling_layers(z,backward=True)
        for i in reversed(range(self.n_coupling)):
            x=self.coupling_layers[i](x,backward=True)
        return (x)
    
    def sample_images(self,number):
        z=self.prior_dist.sample((number,in_dim)).to(device)
        gen_images=self.sampling(z)
        return(gen_images)
    
    def likelihood(self,x):
        #log(p(x))=log(ph(f(x))+log(sii)
        x_,det_jacobian=self.inference(x)
        log_likelihood=torch.sum(self.prior_dist.log_prob(x_),dim=1)
        return(log_likelihood + det_jacobian)
    
    def forward(self,x):
        return(self.likelihood(x))

# %%
class logistic_di(torch.distributions.Distribution):
    def __init__(self):
        super(logistic_di, self).__init__()

    def log_prob(self, x):
        
        return -(F.softplus(x) + F.softplus(-x))

    def sample(self, size):
        z = torch.distributions.Uniform(0., 1.).sample(size).to(device)
        return torch.log(z) - torch.log(1. - z)

# %% [markdown]
# # MNIST generative model

# %%
mean=torch.load("./fashion_mnist_mean.pt")
transforms=torchvision.transforms.ToTensor()
batch_size=200
training_data=torchvision.datasets.FashionMNIST(root='torch/data/MNIST',train=True, download=True, transform=transforms)
train_loader=torch.utils.data.DataLoader(training_data,batch_size=batch_size, shuffle=True, num_workers=2)

validation_data=torchvision.datasets.FashionMNIST(root='torch/data/MNIST',train=False,download=True,transform=transforms)
val_loader=torch.utils.data.DataLoader(validation_data,batch_size=batch_size,shuffle=True,num_workers=2)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to torch/data/MNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting torch/data/MNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz to torch/data/MNIST/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to torch/data/MNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting torch/data/MNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz to torch/data/MNIST/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to torch/data/MNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting torch/data/MNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to torch/data/MNIST/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to torch/data/MNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting torch/data/MNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to torch/data/MNIST/FashionMNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %%
class logistic_distribution(torch.distributions.Distribution):
    def __init__(self):
        super(logistic_distribution, self).__init__()

    def log_prob(self, x):
      likelihood=-F.softplus(x)-F.softplus(-x)
      return (likelihood)

    def sample(self, size):
        z = torch.distributions.Uniform(0., 1.).sample(size).to(device)
        return torch.log(z) - torch.log(1. - z)

# %%
prior_dist=logistic_distribution()
n_coupling=4
in_dim=1*28*28
hidden_dim=1000
hidden_layers=5
flow_model=NICE(prior_dist=prior_dist,n_coupling=n_coupling,in_dim=in_dim,hidden_dim=hidden_dim,hidden_layers=hidden_layers)
flow_model=flow_model.to(device)

# %%
mean=torch.load('./fashion_mnist_mean.pt')
mean=mean.to(device)
optimizer=torch.optim.Adam(flow_model.parameters(),lr=1e-3,betas=(0.9,0.999), eps=1e-8)
total_iter=0
train=True
running_loss=0.0
max_iter=100000
while train==True:
  for batch_idx,data in enumerate(train_loader):
    flow_model.train()
    if total_iter == max_iter:
      train=False
      break
    total_iter+=1
    optimizer.zero_grad()
    
    images,label=data[0],data[1]
    images=images.to(device)
    noise=torch.distributions.Uniform(0.,1.).sample(images.size())
    noise=noise.to(device)
    images=(images*255.+noise)
    images=images/256.
    B,C,H,W=images.size()
    images=images.reshape(B,C*H*W)
    images=images-mean

    loss=-flow_model(images).mean()
    running_loss+=float(loss)

    loss.backward()
    optimizer.step()

    if total_iter%1000 == 0:
      mean_loss=running_loss / 1000
      print("iter %s:" % total_iter, 'loss= %.3f'% mean_loss)
      running_loss=0.0


      flow_model.eval()
      with torch.no_grad():
        z,det=flow_model.inference(images)
        gen_img=flow_model.sampling(z)
        gen_img=gen_img.cpu()
        gen_samples=flow_model.sample_images(64).cpu()
        [B,H]=gen_samples.size()
        assert [H==1*28*28]
        mean_cpu=mean.cpu()
        gen_samples=gen_samples+mean_cpu
        gen_samples=gen_samples.reshape((B,1,28,28))
        torchvision.utils.save_image(torchvision.utils.make_grid(gen_samples),'./new_samples/'+'iter%d.png' % total_iter)
        print("Images saved")
# Out:
# iter 1000: loss= -536.869
# Images saved
# iter 2000: loss= -803.777
# Images saved
# iter 3000: loss= -907.016
ved
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f1471c3c1c22> in <module>()
#       7 max_iter=1000000
#       8 while train==True:
# ----> 9   for batch_idx,data in enumerate(train_loader):
#      10     flow_model.train()
#      11     if total_iter == max_iter:
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     839
#     840             assert not self._shutdown and self._tasks_outstanding > 0
# --> 841             idx, data = self._get_data()
#     842             self._tasks_outstanding -= 1
#     843
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#     806         else:
#     807             while True:
# --> 808                 success, data = self._try_get_data()
#     809                 if success:
#     810                     return data
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     759         #   (bool: whether successfully get data, any: data if successful else None)
#     760         try:
# --> 761             data = self._data_queue.get(timeout=timeout)
#     762             return (True, data)
#     763         except Exception as e:
#
# /usr/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#     111                 self._rlock.release()
#     112         # unserialize the data after having released the lock
# --> 113         return _ForkingPickler.loads(res)
#     114
#     115     def qsize(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py in rebuild_storage_fd(cls, df, size)
#     292                     raise
#     293     else:
# --> 294         fd = df.detach()
#     295     try:
#     296         storage = storage_from_cache(cls, fd_id(fd))
#
# /usr/lib/python3.6/multiprocessing/resource_sharer.py in detach(self)
#      55         def detach(self):
#      56             '''Get the fd.  This should only be called once.'''
# ---> 57             with _resource_sharer.get_connection(self._id) as conn:
#      58                 return reduction.recv_handle(conn)
#      59
#
# /usr/lib/python3.6/multiprocessing/resource_sharer.py in get_connection(ident)
#      85         from .connection import Client
#      86         address, key = ident
# ---> 87         c = Client(address, authkey=process.current_process().authkey)
#      88         c.send((key, os.getpid()))
#      89         return c
#
# /usr/lib/python3.6/multiprocessing/connection.py in Client(address, family, authkey)
#     491
#     492     if authkey is not None:
# --> 493         answer_challenge(c, authkey)
#     494         deliver_challenge(c, authkey)
#     495
#
# /usr/lib/python3.6/multiprocessing/connection.py in answer_challenge(connection, authkey)
#     730     import hmac
#     731     assert isinstance(authkey, bytes)
# --> 732     message = connection.recv_bytes(256)         # reject large message
#     733     assert message[:len(CHALLENGE)] == CHALLENGE, 'message = %r' % message
#     734     message = message[len(CHALLENGE):]
#
# /usr/lib/python3.6/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# /usr/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# /usr/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
# !zip -r ./new_sample_fashion.zip ./new_samples
files.download("./new_sample_fashion.zip")
# Out:
#   adding: new_samples/ (stored 0%)
#   adding: new_samples/iter24000.png (deflated 4%)
#   adding: new_samples/iter289000.png (deflated 3%)
#   adding: new_samples/iter29000.png (deflated 3%)
#   adding: new_samples/iter89000.png (deflated 3%)
#   adding: new_samples/iter300000.png (deflated 3%)
#   adding: new_samples/iter84000.png (deflated 3%)
#   adding: new_samples/iter113000.png (deflated 3%)
#   adding: new_samples/iter149000.png (deflated 3%)
#   adding: new_samples/iter233000.png (deflated 3%)
#   adding: new_samples/iter70000.png (deflated 3%)
#   adding: new_samples/iter34000.png (deflated 3%)
#   adding: new_samples/iter36000.png (deflated 3%)
#   adding: new_samples/iter192000.png (deflated 3%)
#   adding: new_samples/.ipynb_checkpoints/ (stored 0%)
#   adding: new_samples/iter32000.png (deflated 4%)
#   adding: new_samples/iter4000.png (deflated 4%)
#   adding: new_samples/iter166000.png (deflated 3%)
#   adding: new_samples/iter262000.png (deflated 3%)
#   adding: new_samples/iter37000.png (deflated 3%)
#   adding: new_samples/iter19000.png (deflated 3%)
#   adding: new_samples/iter157000.png (deflated 3%)
#   adding: new_samples/iter295000.png (deflated 3%)
#   adding: new_samples/iter161000.png (deflated 3%)
#   adding: new_samples/iter296000.png (deflated 3%)
#   adding: new_samples/iter2000.png (deflated 4%)
#   adding: new_samples/iter148000.png (deflated 3%)
#   adding: new_samples/iter280000.png (deflated 3%)
#   adding: new_samples/iter79000.png (deflated 3%)
#   adding: new_samples/iter263000.png (deflated 3%)
#   adding: new_samples/iter135000.png (deflated 3%)
#   adding: new_samples/iter95000.png (deflated 3%)
#   adding: new_samples/iter224000.png (deflated 3%)
#   adding: new_samples/iter99000.png (deflated 3%)
#   adding: new_samples/iter78000.png (deflated 4%)
#   adding: new_samples/iter246000.png (deflated 4%)
#   adding: new_samples/iter231000.png (deflated 3%)
#   adding: new_samples/iter239000.png (deflated 3%)
#   adding: new_samples/iter177000.png (deflated 3%)
#   adding: new_samples/iter140000.png (deflated 3%)
#   adding: new_samples/iter251000.png (deflated 3%)
#   adding: new_samples/iter45000.png (deflated 3%)
#   adding: new_samples/iter171000.png (deflated 3%)
#   adding: new_samples/iter55000.png (deflated 3%)
#   adding: new_samples/iter199000.png (deflated 3%)
#   adding: new_samples/iter271000.png (deflated 3%)
#   adding: new_samples/iter46000.png (deflated 3%)
#   adding: new_samples/iter144000.png (deflated 3%)
#   adding: new_samples/iter276000.png (deflated 3%)
#   adding: new_samples/iter21000.png (deflated 3%)
#   adding: new_samples/iter186000.png (deflated 3%)
#   adding: new_samples/iter146000.png (deflated 3%)
#   adding: new_samples/iter51000.png (deflated 3%)
#   adding: new_samples/iter97000.png (deflated 3%)
#   adding: new_samples/iter93000.png (deflated 3%)
#   adding: new_samples/iter12000.png (deflated 4%)
#   adding: new_samples/iter176000.png (deflated 4%)
#   adding: new_samples/iter131000.png (deflated 3%)
#   adding: new_samples/iter91000.png (deflated 3%)
#   adding: new_samples/iter243000.png (deflated 3%)
#   adding: new_samples/iter210000.png (deflated 3%)
#   adding: new_samples/iter250000.png (deflated 3%)
#   adding: new_samples/iter217000.png (deflated 3%)
#   adding: new_samples/iter83000.png (deflated 3%)
#   adding: new_samples/iter294000.png (deflated 3%)
#   adding: new_samples/iter122000.png (deflated 3%)
#   adding: new_samples/iter285000.png (deflated 3%)
#   adding: new_samples/iter73000.png (deflated 3%)
#   adding: new_samples/iter163000.png (deflated 3%)
#   adding: new_samples/iter67000.png (deflated 3%)
#   adding: new_samples/iter30000.png (deflated 4%)
#   adding: new_samples/iter71000.png (deflated 3%)
#   adding: new_samples/iter282000.png (deflated 3%)
#   adding: new_samples/iter260000.png (deflated 3%)
#   adding: new_samples/iter236000.png (deflated 3%)
#   adding: new_samples/iter189000.png (deflated 3%)
#   adding: new_samples/iter112000.png (deflated 3%)
#   adding: new_samples/iter74000.png (deflated 3%)
#   adding: new_samples/iter75000.png (deflated 3%)
#   adding: new_samples/iter195000.png (deflated 4%)
#   adding: new_samples/iter267000.png (deflated 3%)
#   adding: new_samples/iter1000.png (deflated 5%)
#   adding: new_samples/iter80000.png (deflated 3%)
#   adding: new_samples/iter3000.png (deflated 4%)
#   adding: new_samples/iter141000.png (deflated 3%)
#   adding: new_samples/iter169000.png (deflated 3%)
#   adding: new_samples/iter44000.png (deflated 3%)
#   adding: new_samples/iter130000.png (deflated 3%)
#   adding: new_samples/iter47000.png (deflated 3%)
#   adding: new_samples/iter160000.png (deflated 3%)
#   adding: new_samples/iter215000.png (deflated 3%)
#   adding: new_samples/iter22000.png (deflated 3%)
#   adding: new_samples/iter197000.png (deflated 3%)
#   adding: new_samples/iter25000.png (deflated 3%)
#   adding: new_samples/iter172000.png (deflated 3%)
#   adding: new_samples/iter26000.png (deflated 3%)
#   adding: new_samples/iter241000.png (deflated 3%)
#   adding: new_samples/iter286000.png (deflated 3%)
#   adding: new_samples/iter121000.png (deflated 3%)
#   adding: new_samples/iter194000.png (deflated 3%)
#   adding: new_samples/iter204000.png (deflated 3%)
#   adding: new_samples/iter115000.png (deflated 4%)
#   adding: new_samples/iter110000.png (deflated 3%)
#   adding: new_samples/iter85000.png (deflated 3%)
#   adding: new_samples/iter7000.png (deflated 4%)
#   adding: new_samples/iter218000.png (deflated 3%)
#   adding: new_samples/iter96000.png (deflated 3%)
#   adding: new_samples/iter145000.png (deflated 3%)
#   adding: new_samples/iter52000.png (deflated 3%)
#   adding: new_samples/iter190000.png (deflated 3%)
#   adding: new_samples/iter103000.png (deflated 3%)
#   adding: new_samples/iter266000.png (deflated 3%)
#   adding: new_samples/iter211000.png (deflated 3%)
#   adding: new_samples/iter152000.png (deflated 3%)
#   adding: new_samples/iter184000.png (deflated 3%)
#   adding: new_samples/iter187000.png (deflated 3%)
#   adding: new_samples/iter82000.png (deflated 3%)
#   adding: new_samples/iter90000.png (deflated 3%)
#   adding: new_samples/iter69000.png (deflated 3%)
#   adding: new_samples/iter120000.png (deflated 3%)
#   adding: new_samples/iter17000.png (deflated 3%)
#   adding: new_samples/iter277000.png (deflated 4%)
#   adding: new_samples/iter128000.png (deflated 3%)
#   adding: new_samples/iter5000.png (deflated 4%)
#   adding: new_samples/iter98000.png (deflated 3%)
#   adding: new_samples/iter59000.png (deflated 3%)
#   adding: new_samples/iter238000.png (deflated 3%)
#   adding: new_samples/iter287000.png (deflated 3%)
#   adding: new_samples/iter261000.png (deflated 4%)
#   adding: new_samples/iter170000.png (deflated 3%)
#   adding: new_samples/iter242000.png (deflated 3%)
#   adding: new_samples/iter142000.png (deflated 3%)
#   adding: new_samples/iter180000.png (deflated 3%)
#   adding: new_samples/iter227000.png (deflated 3%)
#   adding: new_samples/iter150000.png (deflated 3%)
#   adding: new_samples/iter223000.png (deflated 3%)
#   adding: new_samples/iter207000.png (deflated 3%)
#   adding: new_samples/iter178000.png (deflated 3%)
#   adding: new_samples/iter126000.png (deflated 3%)
#   adding: new_samples/iter292000.png (deflated 3%)
#   adding: new_samples/iter216000.png (deflated 3%)
#   adding: new_samples/iter274000.png (deflated 3%)
#   adding: new_samples/iter268000.png (deflated 3%)
#   adding: new_samples/iter40000.png (deflated 3%)
#   adding: new_samples/iter298000.png (deflated 3%)
#   adding: new_samples/iter205000.png (deflated 3%)
#   adding: new_samples/iter173000.png (deflated 3%)
#   adding: new_samples/iter248000.png (deflated 3%)
#   adding: new_samples/iter137000.png (deflated 3%)
#   adding: new_samples/iter201000.png (deflated 3%)
#   adding: new_samples/iter200000.png (deflated 3%)
#   adding: new_samples/iter193000.png (deflated 3%)
#   adding: new_samples/iter100000.png (deflated 3%)
#   adding: new_samples/iter68000.png (deflated 3%)
#   adding: new_samples/iter269000.png (deflated 3%)
#   adding: new_samples/iter151000.png (deflated 3%)
#   adding: new_samples/iter116000.png (deflated 3%)
#   adding: new_samples/iter42000.png (deflated 3%)
#   adding: new_samples/iter54000.png (deflated 3%)
#   adding: new_samples/iter33000.png (deflated 3%)
#   adding: new_samples/iter101000.png (deflated 3%)
#   adding: new_samples/iter181000.png (deflated 3%)
#   adding: new_samples/iter66000.png (deflated 4%)
#   adding: new_samples/iter104000.png (deflated 3%)
#   adding: new_samples/iter230000.png (deflated 3%)
#   adding: new_samples/iter92000.png (deflated 3%)
#   adding: new_samples/iter105000.png (deflated 3%)
#   adding: new_samples/iter191000.png (deflated 4%)
#   adding: new_samples/iter225000.png (deflated 3%)
#   adding: new_samples/iter127000.png (deflated 3%)
#   adding: new_samples/iter281000.png (deflated 3%)
#   adding: new_samples/iter237000.png (deflated 3%)
#   adding: new_samples/iter16000.png (deflated 3%)
#   adding: new_samples/iter247000.png (deflated 4%)
#   adding: new_samples/iter129000.png (deflated 3%)
#   adding: new_samples/iter23000.png (deflated 3%)
#   adding: new_samples/iter283000.png (deflated 3%)
#   adding: new_samples/iter203000.png (deflated 3%)
#   adding: new_samples/iter136000.png (deflated 3%)
#   adding: new_samples/iter8000.png (deflated 4%)
#   adding: new_samples/iter107000.png (deflated 3%)
#   adding: new_samples/iter102000.png (deflated 3%)
#   adding: new_samples/iter81000.png (deflated 3%)
#   adding: new_samples/iter124000.png (deflated 3%)
#   adding: new_samples/iter208000.png (deflated 3%)
#   adding: new_samples/iter220000.png (deflated 3%)
#   adding: new_samples/iter257000.png (deflated 3%)
#   adding: new_samples/iter235000.png (deflated 3%)
#   adding: new_samples/iter188000.png (deflated 3%)
#   adding: new_samples/iter111000.png (deflated 3%)
#   adding: new_samples/iter284000.png (deflated 3%)
#   adding: new_samples/iter264000.png (deflated 3%)
#   adding: new_samples/iter202000.png (deflated 3%)
#   adding: new_samples/iter159000.png (deflated 3%)
#   adding: new_samples/iter182000.png (deflated 3%)
#   adding: new_samples/iter162000.png (deflated 3%)
#   adding: new_samples/iter252000.png (deflated 3%)
#   adding: new_samples/iter14000.png (deflated 3%)
#   adding: new_samples/iter77000.png (deflated 3%)
#   adding: new_samples/iter222000.png (deflated 3%)
#   adding: new_samples/iter273000.png (deflated 3%)
#   adding: new_samples/iter245000.png (deflated 3%)
#   adding: new_samples/iter258000.png (deflated 3%)
#   adding: new_samples/iter297000.png (deflated 4%)
#   adding: new_samples/iter212000.png (deflated 3%)
#   adding: new_samples/iter155000.png (deflated 3%)
#   adding: new_samples/iter185000.png (deflated 3%)
#   adding: new_samples/iter272000.png (deflated 3%)
#   adding: new_samples/iter28000.png (deflated 3%)
#   adding: new_samples/iter147000.png (deflated 3%)
#   adding: new_samples/iter11000.png (deflated 3%)
#   adding: new_samples/iter168000.png (deflated 3%)
#   adding: new_samples/iter18000.png (deflated 3%)
#   adding: new_samples/iter279000.png (deflated 3%)
#   adding: new_samples/iter214000.png (deflated 3%)
#   adding: new_samples/iter164000.png (deflated 3%)
#   adding: new_samples/iter65000.png (deflated 3%)
#   adding: new_samples/iter138000.png (deflated 3%)
#   adding: new_samples/iter196000.png (deflated 3%)
#   adding: new_samples/iter43000.png (deflated 3%)
#   adding: new_samples/iter53000.png (deflated 3%)
#   adding: new_samples/iter232000.png (deflated 3%)
#   adding: new_samples/iter175000.png (deflated 3%)
#   adding: new_samples/iter255000.png (deflated 3%)
#   adding: new_samples/iter132000.png (deflated 3%)
#   adding: new_samples/iter253000.png (deflated 3%)
#   adding: new_samples/iter58000.png (deflated 3%)
#   adding: new_samples/iter270000.png (deflated 3%)
#   adding: new_samples/iter6000.png (deflated 4%)
#   adding: new_samples/iter213000.png (deflated 3%)
#   adding: new_samples/iter244000.png (deflated 3%)
#   adding: new_samples/iter288000.png (deflated 3%)
#   adding: new_samples/iter49000.png (deflated 3%)
#   adding: new_samples/iter38000.png (deflated 3%)
#   adding: new_samples/iter221000.png (deflated 3%)
#   adding: new_samples/iter64000.png (deflated 3%)
#   adding: new_samples/iter86000.png (deflated 3%)
#   adding: new_samples/iter48000.png (deflated 3%)
#   adding: new_samples/iter229000.png (deflated 3%)
#   adding: new_samples/iter206000.png (deflated 3%)
#   adding: new_samples/iter27000.png (deflated 3%)
#   adding: new_samples/iter20000.png (deflated 3%)
#   adding: new_samples/iter56000.png (deflated 3%)
#   adding: new_samples/iter293000.png (deflated 3%)
#   adding: new_samples/iter125000.png (deflated 3%)
#   adding: new_samples/iter226000.png (deflated 3%)
#   adding: new_samples/iter278000.png (deflated 3%)
#   adding: new_samples/iter87000.png (deflated 3%)
#   adding: new_samples/iter275000.png (deflated 3%)
#   adding: new_samples/iter63000.png (deflated 3%)
#   adding: new_samples/iter76000.png (deflated 3%)
#   adding: new_samples/iter9000.png (deflated 3%)
#   adding: new_samples/iter13000.png (deflated 3%)
#   adding: new_samples/iter88000.png (deflated 3%)
#   adding: new_samples/iter50000.png (deflated 4%)
#   adding: new_samples/iter72000.png (deflated 3%)
#   adding: new_samples/iter118000.png (deflated 3%)
#   adding: new_samples/iter198000.png (deflated 3%)
#   adding: new_samples/iter41000.png (deflated 4%)
#   adding: new_samples/iter153000.png (deflated 3%)
#   adding: new_samples/iter234000.png (deflated 3%)
#   adding: new_samples/iter123000.png (deflated 3%)
#   adding: new_samples/iter154000.png (deflated 3%)
#   adding: new_samples/iter156000.png (deflated 3%)
#   adding: new_samples/iter57000.png (deflated 3%)
#   adding: new_samples/iter60000.png (deflated 3%)
#   adding: new_samples/iter94000.png (deflated 3%)
#   adding: new_samples/iter290000.png (deflated 3%)
#   adding: new_samples/iter158000.png (deflated 3%)
#   adding: new_samples/iter299000.png (deflated 3%)
#   adding: new_samples/iter134000.png (deflated 3%)
#   adding: new_samples/iter240000.png (deflated 3%)
#   adding: new_samples/iter183000.png (deflated 3%)
#   adding: new_samples/iter119000.png (deflated 3%)
#   adding: new_samples/iter254000.png (deflated 3%)
#   adding: new_samples/iter167000.png (deflated 3%)
#   adding: new_samples/iter249000.png (deflated 3%)
#   adding: new_samples/iter10000.png (deflated 4%)
#   adding: new_samples/iter106000.png (deflated 3%)
#   adding: new_samples/iter61000.png (deflated 3%)
#   adding: new_samples/iter143000.png (deflated 3%)
#   adding: new_samples/iter62000.png (deflated 3%)
#   adding: new_samples/iter39000.png (deflated 3%)
#   adding: new_samples/iter117000.png (deflated 3%)
#   adding: new_samples/iter35000.png (deflated 3%)
#   adding: new_samples/iter114000.png (deflated 4%)
#   adding: new_samples/iter179000.png (deflated 3%)
#   adding: new_samples/iter291000.png (deflated 3%)
#   adding: new_samples/iter174000.png (deflated 3%)
#   adding: new_samples/iter133000.png (deflated 3%)
#   adding: new_samples/iter228000.png (deflated 3%)
#   adding: new_samples/iter139000.png (deflated 3%)
#   adding: new_samples/iter31000.png (deflated 3%)
#   adding: new_samples/iter259000.png (deflated 3%)
#   adding: new_samples/iter108000.png (deflated 3%)
#   adding: new_samples/iter256000.png (deflated 3%)
#   adding: new_samples/iter265000.png (deflated 3%)
#   adding: new_samples/iter165000.png (deflated 3%)
#   adding: new_samples/iter209000.png (deflated 3%)
#   adding: new_samples/iter15000.png (deflated 3%)
#   adding: new_samples/iter109000.png (deflated 3%)
#   adding: new_samples/iter219000.png (deflated 3%)
